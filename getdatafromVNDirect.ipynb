# %%
from datetime import datetime
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
import time

# %%
chrome_driver_path = 'D:\python\selenium\driver\chromedriver.exe'
chrome_options = Options()
#chrome_options.page_load_strategy
#chrome_options.add_argument('--headless')
chrome_options.add_argument('--user-data-dir=C:\\Users\\hung-pro7\\AppData\\Local\\Google\\Chrome\\User Data\\Default\\Default')
webdriver = webdriver.Chrome(executable_path=chrome_driver_path, options=chrome_options)
url = 'https://trade-hcm.vndirect.com.vn/chung-khoan/hose'
webdriver.get(url)
webdriver.find_element_by_xpath('//*[@id="menuWrp"]/div/a[2]').click()  
time.sleep(2)
webdriver.find_element_by_xpath('//*[@id="login-popup"]/form/div[1]/div/input').send_keys("tuanhungstar")
webdriver.find_element_by_xpath('//*[@id="login-popup"]/form/div[2]/div/input').send_keys("")
webdriver.find_element_by_xpath('//*[@id="login-popup"]/form/button').click()
time.sleep(2)
webdriver.find_element_by_xpath('//*[@id="nav"]/ul[1]/li[2]/a/span').click()
time.sleep(2)

# %%
HOSE_table = webdriver.find_elements_by_class_name('txt-gia-tran')

# %%
HOSE_ticker=[]
for row in HOSE_table:
    text = row.get_attribute('id').replace('ceil','')
    HOSE_ticker.append(text)

# %%
HOSE_ticker
# Out:
# ['AAA',
#  'AAM',
#  'ABS',
#  'ABT',
#  'ACC',
#  'ACL',
#  'ADS',
#  'AGG',
#  'AGM',
#  'AGR',
#  'AMD',
#  'ANV',
#  'APC',
#  'APG',
#  'ASM',
#  'ASP',
#  'AST',
#  'ATG',
#  'BBC',
#  'BCE',
#  'BCG',
#  'BFC',
#  'BHN',
#  'BIC',
#  'BID',
#  'BMC',
#  'BMI',
#  'BMP',
#  'BRC',
#  'BSI',
#  'BTP',
#  'BTT',
#  'BVH',
#  'BWE',
#  'C32',
#  'C47',
#  'CAV',
#  'CCI',
#  'CCL',
#  'CDC',
#  'CDPM2001',
#  'CDPM2002',
#  'CEE',
#  'CFPT1905',
#  'CFPT1906',
#  'CFPT1908',
#  'CFPT2001',
#  'CFPT2002',
#  'CGMD1901',
#  'CGMD2001',
#  'CHDB2001',
#  'CHDB2002',
#  'CHDB2003',
#  'CHDB2004',
#  'CHP',
#  'CHPG1907',
#  'CHPG1909',
#  'CHPG2001',
#  'CHPG2002',
#  'CHPG2003',
#  'CHPG2004',
#  'CIG',
#  'CII',
#  'CKG',
#  'CLC',
#  'CLG',
#  'CLL',
#  'CLW',
#  'CMBB1903',
#  'CMBB1905',
#  'CMBB2001',
#  'CMG',
#  'CMSN1902',
#  'CMSN2001',
#  'CMV',
#  'CMWG1907',
#  'CMWG2001',
#  'CMWG2002',
#  'CMWG2003',
#  'CMWG2004',
#  'CMX',
#  'CNG',
#  'CNVL2001',
#  'COM',
#  'CPNJ2001',
#  'CRC',
#  'CRE',
#  'CREE1903',
#  'CREE1905',
#  'CREE2001',
#  'CROS2001',
#  'CSBT2001',
#  'CSM',
#  'CSTB2001',
#  'CSTB2002',
#  'CSV',
#  'CTCB1902',
#  'CTCB2001',
#  'CTCB2002',
#  'CTD',
#  'CTF',
#  'CTG',
#  'CTI',
#  'CTS',
#  'CVHM1902',
#  'CVHM2001',
#  'CVIC1902',
#  'CVIC1903',
#  'CVIC2001',
#  'CVJC1902',
#  'CVJC2001',
#  'CVNM1903',
#  'CVNM1904',
#  'CVNM1905',
#  'CVNM2001',
#  'CVNM2002',
#  'CVPB2001',
#  'CVPB2002',
#  'CVPB2003',
#  'CVPB2004',
#  'CVRE1902',
#  'CVRE1903',
#  'CVRE2001',
#  'CVRE2002',
#  'CVRE2003',
#  'CVT',
#  'D2D',
#  'DAG',
#  'DAH',
#  'DAT',
#  'DBC',
#  'DBD',
#  'DCL',
#  'DCM',
#  'DGW',
#  'DHA',
#  'DHC',
#  'DHG',
#  'DHM',
#  'DIC',
#  'DIG',
#  'DLG',
#  'DMC',
#  'DPG',
#  'DPM',
#  'DPR',
#  'DQC',
#  'DRC',
#  'DRH',
#  'DRL',
#  'DSN',
#  'DTA',
#  'DTL',
#  'DTT',
#  'DVP',
#  'DXG',
#  'DXV',
#  'E1VFVN30',
#  'EIB',
#  'ELC',
#  'EMC',
#  'EVE',
#  'EVG',
#  'FCM',
#  'FCN',
#  'FDC',
#  'FIR',
#  'FIT',
#  'FLC',
#  'FMC',
#  'FPT',
#  'FRT',
#  'FTM',
#  'FTS',
#  'FUCTVGF1',
#  'FUCTVGF2',
#  'FUCVREIT',
#  'FUESSV50',
#  'FUESSVFL',
#  'GAB',
#  'GAS',
#  'GDT',
#  'GEG',
#  'GEX',
#  'GIL',
#  'GMC',
#  'GMD',
#  'GSP',
#  'GTA',
#  'GTN',
#  'GVR',
#  'HAG',
#  'HAH',
#  'HAI',
#  'HAP',
#  'HAR',
#  'HAS',
#  'HAX',
#  'HBC',
#  'HCD',
#  'HCM',
#  'HDB',
#  'HDC',
#  'HDG',
#  'HHS',
#  'HID',
#  'HII',
#  'HMC',
#  'HNG',
#  'HOT',
#  'HPG',
#  'HPX',
#  'HQC',
#  'HRC',
#  'HSG',
#  'HSL',
#  'HT1',
#  'HTI',
#  'HTL',
#  'HTN',
#  'HTT',
#  'HTV',
#  'HU1',
#  'HU3',
#  'HUB',
#  'HVG',
#  'HVH',
#  'HVN',
#  'HVX',
#  'IBC',
#  'ICT',
#  'IDI',
#  'IJC',
#  'ILB',
#  'IMP',
#  'ITA',
#  'ITC',
#  'ITD',
#  'JVC',
#  'KBC',
#  'KDC',
#  'KDH',
#  'KHP',
#  'KMR',
#  'KOS',
#  'KPF',
#  'KSB',
#  'L10',
#  'LAF',
#  'LBM',
#  'LCG',
#  'LCM',
#  'LDG',
#  'LEC',
#  'LGC',
#  'LGL',
#  'LHG',
#  'LIX',
#  'LM8',
#  'LMH',
#  'LSS',
#  'MBB',
#  'MCG',
#  'MCP',
#  'MDG',
#  'MHC',
#  'MSH',
#  'MSN',
#  'MWG',
#  'NAF',
#  'NAV',
#  'NBB',
#  'NCT',
#  'NHH',
#  'NKG',
#  'NLG',
#  'NNC',
#  'NSC',
#  'NT2',
#  'NTL',
#  'NVL',
#  'NVT',
#  'OGC',
#  'OPC',
#  'PAC',
#  'PAN',
#  'PC1',
#  'PDN',
#  'PDR',
#  'PET',
#  'PGC',
#  'PGD',
#  'PGI',
#  'PHC',
#  'PHR',
#  'PIT',
#  'PJT',
#  'PLP',
#  'PLX',
#  'PME',
#  'PMG',
#  'PNC',
#  'PNJ',
#  'POM',
#  'POW',
#  'PPC',
#  'PTB',
#  'PTC',
#  'PTL',
#  'PVD',
#  'PVT',
#  'PXI',
#  'PXS',
#  'PXT',
#  'QBS',
#  'QCG',
#  'RAL',
#  'RDP',
#  'REE',
#  'RIC',
#  'ROS',
#  'S4A',
#  'SAB',
#  'SAM',
#  'SAV',
#  'SBA',
#  'SBT',
#  'SBV',
#  'SC5',
#  'SCD',
#  'SCR',
#  'SCS',
#  'SFC',
#  'SFG',
#  'SFI',
#  'SGN',
#  'SGR',
#  'SGT',
#  'SHA',
#  'SHI',
#  'SHP',
#  'SII',
#  'SJD',
#  'SJF',
#  'SJS',
#  'SKG',
#  'SMA',
#  'SMB',
#  'SMC',
#  'SPM',
#  'SRC',
#  'SRF',
#  'SSC',
#  'SSI',
#  'ST8',
#  'STB',
#  'STG',
#  'STK',
#  'SVC',
#  'SVI',
#  'SVT',
#  'SZC',
#  'SZL',
#  'TAC',
#  'TBC',
#  'TCB',
#  'TCD',
#  'TCH',
#  'TCL',
#  'TCM',
#  'TCO',
#  'TCR',
#  'TCT',
#  'TDC',
#  'TDG',
#  'TDH',
#  'TDM',
#  'TDW',
#  'TEG',
#  'TGG',
#  'THG',
#  'THI',
#  'TIP',
#  'TIX',
#  'TLD',
#  'TLG',
#  'TLH',
#  'TMP',
#  'TMS',
#  'TMT',
#  'TN1',
#  'TNA',
#  'TNC',
#  'TNI',
#  'TNT',
#  'TPB',
#  'TPC',
#  'TRA',
#  'TRC',
#  'TS4',
#  'TSC',
#  'TTB',
#  'TTE',
#  'TTF',
#  'TV2',
#  'TVB',
#  'TVS',
#  'TVT',
#  'TYA',
#  'UDC',
#  'UIC',
#  'VAF',
#  'VCB',
#  'VCF',
#  'VCI',
#  'VDP',
#  'VDS',
#  'VFG',
#  'VGC',
#  'VHC',
#  'VHM',
#  'VIC',
#  'VID',
#  'VIP',
#  'VIS',
#  'VJC',
#  'VMD',
#  'VND',
#  'VNE',
#  'VNG',
#  'VNL',
#  'VNM',
#  'VNS',
#  'VOS',
#  'VPB',
#  'VPD',
#  'VPG',
#  'VPH',
#  'VPI',
#  'VPS',
#  'VRC',
#  'VRE',
#  'VSC',
#  'VSH',
#  'VSI',
#  'VTB',
#  'VTO',
#  'YBM',
#  'YEG']

# %%
AGMmatchP

# %%
Stock_name = []
ceil_price =[]
ref_price =[]
floor_price =[]
match_price=[]
vol=[]
NN_buy =[]
NN_sell=[]
for stock in HOSE_ticker:
    ceil_price.append(webdriver.find_element_by_id(str(stock)+'matchP').text)
    Stock_name.append(stock)

# %%
len(Stock_name)
# Out:
# 449

# %%
ceil_price
# Out:
# ['10.30',
#  '11.80',
#  '26.90',
#  '33.70',
#  '19.00',
#  '17.50',
#  '9.95',
#  '28.00',
#  '10.05',
#  '2.41',
#  '3.13',
#  '13.90',
#  '13.60',
#  '8.21',
#  '3.63',
#  '5.09',
#  '43.50',
#  '0.60',
#  '46.50',
#  '6.50',
#  '4.62',
#  '10.30',
#  '43.20',
#  '25.00',
#  '34.30',
#  '9.60',
#  '15.50',
#  '36.00',
#  '11.20',
#  '8.49',
#  '12.00',
#  '',
#  '42.30',
#  '16.95',
#  '20.10',
#  '7.18',
#  '58.30',
#  '13.35',
#  '4.38',
#  '12.50',
#  '0.35',
#  '1.85',
#  '17.75',
#  '0.17',
#  '0.01',
#  '0.29',
#  '0.15',
#  '0.29',
#  '0.02',
#  '0.03',
#  '0.09',
#  '0.02',
#  '0.63',
#  '0.03',
#  '17.80',
#  '0.02',
#  '0.08',
#  '0.17',
#  '0.58',
#  '0.11',
#  '0.33',
#  '1.80',
#  '18.75',
#  '7.62',
#  '24.10',
#  '1.77',
#  '28.60',
#  '',
#  '0.04',
#  '0.01',
#  '0.09',
#  '24.00',
#  '0.07',
#  '1.45',
#  '18.45',
#  '0.01',
#  '0.06',
#  '0.10',
#  '0.02',
#  '0.36',
#  '10.40',
#  '19.25',
#  '1.64',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
webdriver.find_element_by_id(str(HOSE_ticker[448])+'ceil').text
# Out:
# ''
